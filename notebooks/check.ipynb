# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.empty(3)
plt.plot(a)
plt.title('test plot to check it cleared on push')
# Out:
# Text(0.5, 1.0, 'test plot to check it cleared on push')
